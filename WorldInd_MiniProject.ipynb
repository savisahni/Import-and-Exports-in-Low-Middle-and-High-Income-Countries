# %% [markdown]
# # Export and Import Analysis for a country based on the Income Group
# The goal of this analysis to find out if there are any trends or patterns in the Export and Import percentages of Low Income, Medium Income and High Income countries

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'C:\Users\savir\Data\Indicators.csv')
data.shape
# Out:
# (5656458, 6)

# %%
countries = data['CountryName'].unique().tolist()
indicators = data['IndicatorName'].unique().tolist()

# %%
incomes = ['Middle income', 'High income', 'Low income']
year = [2008,2010,2012,2013,2015,2016]

data_1 = data[data.CountryName.isin(incomes)]

# %%
data_2 = data_1[data_1.Year.isin(year)]

# %%
data_import = data_2[data_2['IndicatorName'] == 'Imports of goods and services (% of GDP)']

# %%
data_import.head()
# Out:
#            CountryName CountryCode                             IndicatorName  \
# 4487750    High income         HIC  Imports of goods and services (% of GDP)
# 4492559     Low income         LIC  Imports of goods and services (% of GDP)
# 4495618  Middle income         MIC  Imports of goods and services (% of GDP)
# 4846544    High income         HIC  Imports of goods and services (% of GDP)
# 4851563     Low income         LIC  Imports of goods and services (% of GDP)
#
#           IndicatorCode  Year      Value
# 4487750  NE.IMP.GNFS.ZS  2008  29.512676
# 4492559  NE.IMP.GNFS.ZS  2008  41.048169
# 4495618  NE.IMP.GNFS.ZS  2008  30.917863
# 4846544  NE.IMP.GNFS.ZS  2010  27.790484
# 4851563  NE.IMP.GNFS.ZS  2010  40.956192

# %%
data_import.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 4487750 to 5390793
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    12 non-null     object
#  1   CountryCode    12 non-null     object
#  2   IndicatorName  12 non-null     object
#  3   IndicatorCode  12 non-null     object
#  4   Year           12 non-null     int64
#  5   Value          12 non-null     float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 672.0+ bytes

# %%
print(data_import)
# Out:
#            CountryName CountryCode                             IndicatorName  \
# 4487750    High income         HIC  Imports of goods and services (% of GDP)
# 4492559     Low income         LIC  Imports of goods and services (% of GDP)
# 4495618  Middle income         MIC  Imports of goods and services (% of GDP)
# 4846544    High income         HIC  Imports of goods and services (% of GDP)
# 4851563     Low income         LIC  Imports of goods and services (% of GDP)
# 4854808  Middle income         MIC  Imports of goods and services (% of GDP)
# 5209239    High income         HIC  Imports of goods and services (% of GDP)
# 5213982     Low income         LIC  Imports of goods and services (% of GDP)
# 5216921  Middle income         MIC  Imports of goods and services (% of GDP)
# 5383799    High income         HIC  Imports of goods and services (% of GDP)
# 5388108     Low income         LIC  Imports of goods and services (% of GDP)
# ...

# %%
fig, ax = plt.subplots(figsize=(25, 15))
sns.set_context('talk')
x = np.arange(len(data_import.Year.unique()))
bar_width = 0.2
b1 = ax.bar(x, data_import.loc[data_import['CountryName'] == 'High income', 'Value'],
            width=bar_width, label = 'High income')
b2 = ax.bar(x + bar_width, data_import.loc[data_import['CountryName'] == 'Middle income', 'Value'],
            width=bar_width, label = 'Middle income')
b3 = ax.bar(x + bar_width + bar_width, data_import.loc[data_import['CountryName'] == 'Low income', 'Value'],
            width=bar_width, label = 'Low income')

# Fix the x-axes.
ax.set_xticks(x + bar_width / 2)
ax.set_xticklabels(data_import.Year.unique())

# Add legend.
ax.legend()

# Axis styling.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

# Add axis and chart labels.
ax.set_xlabel('Income Group', labelpad=15)
ax.set_ylabel('Imports of goods and services (% of GDP)', labelpad=15)
ax.set_title('Imports of goods and services (% of GDP) based on countrys Income Group', pad=15)
# Out:
# Text(0.5, 1.0, 'Imports of goods and services (% of GDP) based on countrys Income Group')

# %%
data_export = data_2[data_2['IndicatorName'] == 'Exports of goods and services (% of GDP)']

# %%
fig, ax = plt.subplots(figsize=(25, 15))
sns.set_context('talk')
x = np.arange(len(data_export.Year.unique()))
bar_width = 0.2
b1 = ax.bar(x, data_export.loc[data_export['CountryName'] == 'High income', 'Value'],
            width=bar_width, label = 'High income')
b2 = ax.bar(x + bar_width, data_export.loc[data_export['CountryName'] == 'Middle income', 'Value'],
            width=bar_width, label = 'Middle income')
b3 = ax.bar(x + bar_width + bar_width, data_export.loc[data_export['CountryName'] == 'Low income', 'Value'],
            width=bar_width, label = 'Low income')

# Fix the x-axes.
ax.set_xticks(x + bar_width / 2)
ax.set_xticklabels(data_export.Year.unique())

# Add legend.
ax.legend()

# Axis styling.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

# Add axis and chart labels.
ax.set_xlabel('Income Group', labelpad=15)
ax.set_ylabel('Export of goods and services (% of GDP)', labelpad=15)
ax.set_title('Export of goods and services (% of GDP) based on countrys Income Group', pad=15)
# Out:
# Text(0.5, 1.0, 'Export of goods and services (% of GDP) based on countrys Income Group')

# %% [markdown]
# # Conclusion
#
# Looking at the above graphs some patterns seem very obvious over the years:
# 1. Import percentages in Low Income countries are relatively high as compared to Import percentages in the High and Middle Income countires.
# 2. We can see this trend continuouly from 2008 - 2013
# 3. This might be due to in inability of low income countries to manage, procure, implement and finance production of goods and services in their own countries.
# 4. Since the countries are import a lot of stuff this might be resulting in low income for the countries due to lack of producing more job, imported goods & service might be more expensive etc.
# 5. Looking at the Export graph, we see that the export percentages in low income countries is lower than the exports from high and middle income countires
# 6. Again this shows that low income countries are lacking the capacity and capability to produced goods and service which in turn results in low job opportunities, higher unemployment rate and lower income groups
